# %%
import jax.numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
import pandas as pd
from sklearn.datasets import load_iris
import joypy

# %%
iris, y = load_iris(as_frame=True, return_X_y=True)
iris.columns = ["SepalLength","SepalWidth","PetalLength","PetalWidth"]
iris["Name"] = y.replace([0,1,2], ['setosa', 'versicolor', 'virginica'])

# %%
iris
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth       Name
# 0            5.1         3.5          1.4         0.2     setosa
# 1            4.9         3.0          1.4         0.2     setosa
# 2            4.7         3.2          1.3         0.2     setosa
# 3            4.6         3.1          1.5         0.2     setosa
# 4            5.0         3.6          1.4         0.2     setosa
# ..           ...         ...          ...         ...        ...
# 145          6.7         3.0          5.2         2.3  virginica
# 146          6.3         2.5          5.0         1.9  virginica
# 147          6.5         3.0          5.2         2.0  virginica
# 148          6.2         3.4          5.4         2.3  virginica
# 149          5.9         3.0          5.1         1.8  virginica
#
# [150 rows x 5 columns]

# %%
# %matplotlib inline

fig, axes = joypy.joyplot(iris)

# %%
Ws = np.load("Ws.npz")
# Out:
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
xs = np.load("xs.npz")

# %%
[f'x{i}' for i in range(1,11)]
# Out:
# ['x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8', 'x9', 'x10']

# %%
Ws_df = pd.DataFrame(Ws,columns=[f'x{i}' for i in range(1,11)])
Ws_df.head()
# Out:
#          x1        x2        x3        x4        x5        x6        x7
# 0 -0.348685 -0.365546 -0.374797 -0.381208 -0.385694 -0.386607 -0.385230  \
# 1 -0.347439 -0.363084 -0.368354 -0.368179 -0.365665 -0.364916 -0.366003
# 2 -0.343715 -0.355930 -0.352882 -0.346746 -0.345052 -0.345501 -0.344967
# 3 -0.337547 -0.344715 -0.336169 -0.335906 -0.338892 -0.338506 -0.338757
# 4 -0.328995 -0.330290 -0.322776 -0.326460 -0.323403 -0.323329 -0.323780
#
#          x8        x9       x10
# 0 -0.380087 -0.373727 -0.364246
# 1 -0.368485 -0.368017 -0.362054
# 2 -0.347664 -0.353734 -0.355599
# 3 -0.335150 -0.337043 -0.345219
# 4 -0.326155 -0.322536 -0.331422

# %%
Ws_df.plot()
# Out:
# <Axes: >

# %%
[x for x in xs]
# Out:
# [Array(0.01, dtype=float32),
#  Array(0.11, dtype=float32),
#  Array(0.21, dtype=float32),
#  Array(0.31, dtype=float32),
#  Array(0.41, dtype=float32),
#  Array(0.51, dtype=float32),
#  Array(0.61, dtype=float32),
#  Array(0.71, dtype=float32),
#  Array(0.81, dtype=float32),
#  Array(0.91, dtype=float32)]

# %%
fig, axes = joypy.joyplot(Ws_df,kind="values",x_range = list(xs),colormap=cm.autumn_r)

# %%
Ws_df.head()
# Out:
#          p1        p2        p3        p4        p5        p6        p7
# 0 -0.348685 -0.347439 -0.343715 -0.337547 -0.328995 -0.318140 -0.305086  \
# 1 -0.365546 -0.363084 -0.355930 -0.344715 -0.330290 -0.313508 -0.295043
# 2 -0.374797 -0.368354 -0.352882 -0.336169 -0.322776 -0.311135 -0.296990
# 3 -0.381208 -0.368179 -0.346746 -0.335906 -0.326460 -0.309952 -0.293554
# 4 -0.385694 -0.365665 -0.345052 -0.338892 -0.323403 -0.309483 -0.295019
#
#          p8        p9       p10
# 0 -0.289956 -0.272897 -0.254069
# 1 -0.275300 -0.254447 -0.232531
# 2 -0.278271 -0.256136 -0.232539
# 3 -0.277943 -0.256904 -0.232350
# 4 -0.275811 -0.256813 -0.232791

# %%
fig, axes = joypy.joyplot(Ws_df,x_range=list(range(10)),kind="values")

# %%
plt.plot(xs, Ws[0,:])
plt.show()
